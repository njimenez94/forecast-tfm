# %%
import kaggle

kaggle.api.authenticate()

busquedas = ["m5 forecasting", "titanic", "house prices", "iris"]

for termino in busquedas:
    print(f"\n=== Resultados para: {termino} ===")
    datasets = kaggle.api.dataset_list(search=termino, sort_by="votes")
    for d in datasets[:5]:
        print(f"{d.title} | votos: {d.vote_count} | descargas: {d.download_count} | usabilidad: {d.usability_rating} | kernels: {d.kernel_count}")
# Out:
# === Resultados para: m5 forecasting ===
# US Public Food Assistance 1 - WIC | votos: 525 | descargas: 34914 | usabilidad: 0.9411765 | kernels: 6129
# US Natural Disaster Declarations | votos: 153 | descargas: 7010 | usabilidad: 1 | kernels: 14
# M5 - AUX models | votos: 57 | descargas: 2146 | usabilidad: 1 | kernels: 13
# M5 Accuracy Final Public LB | votos: 13 | descargas: 530 | usabilidad: 0.9411765 | kernels: 11
# M5 Accuracy - Preprocessed Datasets | votos: 3 | descargas: 253 | usabilidad: 0.9117647 | kernels: 2
#
# === Resultados para: titanic ===
# Titanic | votos: 2123 | descargas: 166699 | usabilidad: 0.7058824 | kernels: 612
# Titanic dataset | votos: 1971 | descargas: 253678 | usabilidad: 1 | kernels: 816
# Big Data Certification KR | votos: 1537 | descargas: 31057 | usabilidad: 0.8235294 | kernels: 1559
# Titanic Dataset | votos: 1178 | descargas: 386293 | usabilidad: 1 | kernels: 867
# Titanic-Dataset (train.csv) | votos: 611 | descargas: 122395 | usabilidad: 0.4117647 | kernels: 356
#
# === Resultados para: house prices ===
# House Sales in King County, USA | votos: 2336 | descargas: 251171 | usabilidad: 0.7058824 | kernels: 1556
# California Housing Prices | votos: 1709 | descargas: 322052 | usabilidad: 0.85294116 | kernels: 1512
# Big Data Certification KR | votos: 1537 | descargas: 31057 | usabilidad: 0.8235294 | kernels: 1559
# House price prediction | votos: 913 | descargas: 144614 | usabilidad: 0.64705884 | kernels: 513
# Boston House Prices | votos: 882 | descargas: 202915 | usabilidad: 0.8235294 | kernels: 490
#
# === Resultados para: iris ===
# Iris Species | votos: 4903 | descargas: 928074 | usabilidad: 0.7941176 | kernels: 8167
# Iris Flower Dataset | votos: 1143 | descargas: 255591 | usabilidad: 0.8235294 | kernels: 1587
# Palmer Archipelago (Antarctica) penguin data  | votos: 760 | descargas: 127084 | usabilidad: 0.9705882 | kernels: 440
# Iris dataset | votos: 434 | descargas: 111496 | usabilidad: 1 | kernels: 400
# Iris.csv | votos: 412 | descargas: 232563 | usabilidad: 0.4117647 | kernels: 241
